# %% [markdown]
# ## **Step 1: Import Pandas Library**

# %%
import pandas as pd

# %% [markdown]
# ## **Step 2: Load & View CSV**

# %%
# df = pd.read_excel("python_data_analytics_ecommerce_raw.xlsx")
df = pd.read_csv("python_data_analytics_ecommerce_raw.csv")

# %%
df.head(15)
# Out:
#        OrderID OrderDate CustomerID CustomerType     Region State  \
# 0   ORD-110092  ########  CUST-1600    Returning       West    CA
# 1   ORD-102705  ########  CUST-6641    Returning  Northeast    CT
# 2   ORD-103027  ########  CUST-2542          New  Southeast    NC
# 3   ORD-102280  2/3/2026  CUST-6731          New       West    AZ
# 4   ORD-103454  ########  CUST-3695    Returning       West    AZ
# 5   ORD-111259  ########  CUST-5717          VIP       West    AZ
# 6   ORD-107532  6/4/2026  CUST-5159          New  southeast    NC
# 7   ORD-107214  ########  CUST-5383    Returning  Southeast    NC
# 8   ORD-110510  4/8/2026  CUST-5252    Returning  Southwest    NM
# 9   ORD-101158  1/4/2026  CUST-3339    Returning  Southwest    TX
# 10  ORD-106536  ########  CUST-6629          New  Northeast    CT
# 11  ORD-106335  ########  CUST-1370          New  Northeast    MA
# 12  ORD-108801  ########  CUST-1911    Returning  Southeast    TN
# 13  ORD-104387  ########  CUST-4931    Returning  Southwest    NM
# 14  ORD-109151  ########  CUST-5541    Returning       West    OR
#
#             Product       Category  Quantity UnitPrice  Discount  \
# 0    Wireless Mouse    Electronics         2     36.48      0.00
# 1         USB-C Hub    Electronics         1     41.12      0.10
# 2            Jacket       Clothing         1    122.56      0.15
# 3       Foam Roller        Fitness         1     26.55      0.00
# 4       Smart Watch    Electronics         1    151.36      0.15
# 5     Standing Desk  Home & Office         1    346.78      0.10
# 6         Desk Lamp  Home & Office         2     47.84      0.00
# 7            Jacket       Clothing         3    120.82      0.05
# 8      Office Chair  Home & Office         3    180.22      0.00
# 9      Dumbbell Set        Fitness         1    133.55      0.00
# 10      Smart Watch    Electronics         2    150.59      0.00
# 11    Standing Desk  Home & Office         1   $326.38      0.10
# 12        Desk Lamp  Home & Office         2     46.03      0.10
# 13    Running Shoes       Clothing         1     84.75      0.05
# 14  Fitness Tracker        Fitness         1     80.78      0.05
#
#     SalesChannel  PaymentMethod ShippingMethod Returned  CustomerRating
# 0   Retail Store      Apple Pay          2-Day       No             3.0
# 1         Online      Apple Pay       Next Day       No             NaN
# 2         Online  Bank Transfer        Express       No             3.0
# 3    Marketplace    Credit Card        Express       No             5.0
# 4   Retail Store    Credit Card       Standard       No             3.0
# 5   Retail Store         PayPal       Standard       No             4.0
# 6         Online     Debit Card        Express       No             1.0
# 7         Online     Debit Card        Express       No             NaN
# 8         Online     Debit Card          2-Day       No             5.0
# 9         Online     Debit Card        Express       No             5.0
# 10        Online         PayPal        Express       No             NaN
# 11     Corporate  Bank Transfer       Standard       No             4.0
# 12        Online     Debit Card       Standard       No             4.0
# 13  Retail Store  Bank Transfer          2-Day       No             4.0
# 14        Online    Credit Card        Express       No             5.0

# %% [markdown]
# ## **Step 3: Check the size of the dataset**

# %%
df.shape
# Out:
# (12500, 16)

# %% [markdown]
# ## **Step 4: Look at column names**

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerType', 'Region', 'State',
#        'Product', 'Category', 'Quantity', 'UnitPrice', 'Discount',
#        'SalesChannel', 'PaymentMethod', 'ShippingMethod', 'Returned',
#        'CustomerRating'],
#       dtype='str')

# %% [markdown]
# ## **Step 5: Understand the datatypes**

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12500 entries, 0 to 12499
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         12500 non-null  str
#  1   OrderDate       12475 non-null  str
#  2   CustomerID      12500 non-null  str
#  3   CustomerType    12372 non-null  str
#  4   Region          12453 non-null  str
#  5   State           12500 non-null  str
#  6   Product         12500 non-null  str
#  7   Category        12405 non-null  str
#  8   Quantity        12500 non-null  int64
#  9   UnitPrice       12500 non-null  str
#  10  Discount        12500 non-null  float64
#  11  SalesChannel    12500 non-null  str
#  12  PaymentMethod   12500 non-null  str
#  13  ShippingMethod  12412 non-null  str
#  14  Returned        12500 non-null  str
#  15  CustomerRating  11241 non-null  float64
# dtypes: float64(2), int64(1), str(13)
# memory usage: 1.5 MB

# %% [markdown]
# ## **Step 6: Find missing values in the data**

# %%
# df.isnull()
df.isnull().sum()
# Out:
# OrderID              0
# OrderDate           25
# CustomerID           0
# CustomerType       128
# Region              47
# State                0
# Product              0
# Category            95
# Quantity             0
# UnitPrice            0
# Discount             0
# SalesChannel         0
# PaymentMethod        0
# ShippingMethod      88
# Returned             0
# CustomerRating    1259
# dtype: int64

# %% [markdown]
# ## **Step 7: Find duplicate rows in the data**

# %%
df.duplicated().sum()
# Out:
# np.int64(150)

# %%
df[df.duplicated()].head()
# Out:
#          OrderID OrderDate CustomerID CustomerType     Region State  \
# 1027  ORD-100081  ########  CUST-6409    Returning    Midwest    MO
# 1036  ORD-102387  9/3/2025  CUST-4725          New  Southeast    GA
# 1621  ORD-102364  ########  CUST-4056          New  Southeast    VA
# 1832  ORD-109830  ########  CUST-2754    Returning  Southeast    GA
# 2133  ORD-101815  ########  CUST-4181          VIP  Northeast    CT
#
#             Product       Category  Quantity UnitPrice  Discount  \
# 1027        T-Shirt       Clothing         1     25.56      0.05
# 1036   Notebook Set  Home & Office         4     18.16      0.05
# 1621       Yoga Mat        Fitness         1     35.89      0.10
# 1832  Standing Desk  Home & Office         2    326.38      0.05
# 2133   Office Chair  Home & Office         1    177.94      0.10
#
#       SalesChannel  PaymentMethod ShippingMethod Returned  CustomerRating
# 1027  Retail Store      Apple Pay       Standard       No             5.0
# 1036        Online         PayPal        Express       No             3.0
# 1621  Retail Store    Credit Card        Express       No             4.0
# 1832        Online  Bank Transfer       Standard       No             3.0
# 2133   Marketplace     Debit Card       Standard       No             4.0

# %% [markdown]
# ## **Step 8: Remove exact duplicate rows in the data**
#
# ### **`drop_duplicates()`:**
#
# * **`df.drop_duplicates()`:** removes **duplicate rows**, not individual repeated values.
#
# * By default, Pandas compares **all columns** to determine whether two rows are duplicates.
#
# * If two rows are completely identical, Pandas keeps the first occurrence and removes the others.
#
# * Repeated values in a single column are **not necessarily duplicates**.
#
# * For example, the same `CustomerID` or `Product` can appear in multiple valid orders.
#
# * **To check duplicated rows before removing them:** `df[df.duplicated()]`
#
# * **To count the number of duplicated rows:** `df.duplicated().sum()`
#
# * **To remove duplicated rows:** `df = df.drop_duplicates()`
#
# **Important:** `drop_duplicates()` removes only rows that are duplicated based on the selected columns. It does not remove every repeated value in the dataset.

# %%
df = df.drop_duplicates()
df.head(10)
# Out:
#       OrderID OrderDate CustomerID CustomerType     Region State  \
# 0  ORD-110092  ########  CUST-1600    Returning       West    CA
# 1  ORD-102705  ########  CUST-6641    Returning  Northeast    CT
# 2  ORD-103027  ########  CUST-2542          New  Southeast    NC
# 3  ORD-102280  2/3/2026  CUST-6731          New       West    AZ
# 4  ORD-103454  ########  CUST-3695    Returning       West    AZ
# 5  ORD-111259  ########  CUST-5717          VIP       West    AZ
# 6  ORD-107532  6/4/2026  CUST-5159          New  southeast    NC
# 7  ORD-107214  ########  CUST-5383    Returning  Southeast    NC
# 8  ORD-110510  4/8/2026  CUST-5252    Returning  Southwest    NM
# 9  ORD-101158  1/4/2026  CUST-3339    Returning  Southwest    TX
#
#           Product       Category  Quantity UnitPrice  Discount  SalesChannel  \
# 0  Wireless Mouse    Electronics         2     36.48      0.00  Retail Store
# 1       USB-C Hub    Electronics         1     41.12      0.10        Online
# 2          Jacket       Clothing         1    122.56      0.15        Online
# 3     Foam Roller        Fitness         1     26.55      0.00   Marketplace
# 4     Smart Watch    Electronics         1    151.36      0.15  Retail Store
# 5   Standing Desk  Home & Office         1    346.78      0.10  Retail Store
# 6       Desk Lamp  Home & Office         2     47.84      0.00        Online
# 7          Jacket       Clothing         3    120.82      0.05        Online
# 8    Office Chair  Home & Office         3    180.22      0.00        Online
# 9    Dumbbell Set        Fitness         1    133.55      0.00        Online
#
#    PaymentMethod ShippingMethod Returned  CustomerRating
# 0      Apple Pay          2-Day       No             3.0
# 1      Apple Pay       Next Day       No             NaN
# 2  Bank Transfer        Express       No             3.0
# 3    Credit Card        Express       No             5.0
# 4    Credit Card       Standard       No             3.0
# 5         PayPal       Standard       No             4.0
# 6     Debit Card        Express       No             1.0
# 7     Debit Card        Express       No             NaN
# 8     Debit Card          2-Day       No             5.0
# 9     Debit Card        Express       No             5.0

# %%
df.shape
# Out:
# (12350, 16)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## **Step 9: Clean text columns**
#
# * #### **`.value_counts()`**
#
#     * **`.value_counts()`:** counts the **number of occurrences of each unique value** in a Series or column.
#
#     * It is useful for understanding the **distribution of categorical data**.
#
#     * By default, the results are sorted from the **most frequent value to the least frequent value**.
#
#     **Common use:** Checking the distribution of categories and detecting unexpected or inconsistent values during data cleaning.
#
# * #### **`str.title()`**
#
#     * **`.str.title()`:** converts a string so that the **first letter of each word is capitalized** and the remaining letters are lowercase.
#
#     * It is useful for **standardizing text formatting** during data cleaning.
#
#     This helps make categorical values consistent and easier to analyze.
#
# * #### **Why do we use `.str`?**
#
#     * **A single Python string can directly use string methods such as `.title()` and `.strip()`:**
#     `text.title()`
#     `text.strip()`
#
#     * However, a Pandas column is a **Series**, not a single string.
#
#     * To apply string methods to every value in a Pandas Series, we use the `.str` accessor.
#     `df["Region"].str.title()`
#     `df["Region"].str.strip()`
#
#     * `.str` tells Pandas to apply the following **string operation element-wise** to the values in the Series.
#
#     **In short:**
#
#     ```text
#     Single String  →  .title() / .strip()
#     Pandas Series  →  .str.title() / .str.strip()
#     ```
#
# * #### **`dropna=False in value_counts()`:**
#     * `df["Category"].value_counts(dropna=False)`
#
#     * **`value_counts()`:** counts how many times each unique value appears
#
#     * By default, `value_counts()` ignores missing values (NaN).
#
#     * `dropna=False` tells Pandas to include NaN values in the count.
#
#     * **Example:**
#
#         ```text python
#         A      3
#
#         B      2
#
#         NaN    2
#
#         So:
#
#         value_counts()                  # ignores NaN
#         value_counts(dropna=False)      # includes NaN
#         ```
#
#     **💡 Useful for EDA:** It helps you see both the distribution of values and the number of missing values in a column.

# %%
df["Category"].value_counts(dropna=False)
# Out:
# Category
# Electronics      3959
# Home & Office    2913
# Clothing         2675
# Fitness          2077
# ELECTRONICS       116
# electronics       107
# NaN                94
# home & office      92
# HOME & OFFICE      85
# clothing           79
# FITNESS            52
# CLOTHING           52
# fitness            49
# Name: count, dtype: int64

# %%
df["Category"] = df["Category"].str.strip().str.title()

# %%
df["Category"].value_counts(dropna=False)
# Out:
# Category
# Electronics      4182
# Home & Office    3090
# Clothing         2806
# Fitness          2178
# NaN                94
# Name: count, dtype: int64

# %%
df["CustomerType"].value_counts(dropna=False)
# Out:
# CustomerType
# Returning    6623
# New          3935
# VIP          1237
# RETURNING     137
# NaN           126
# returning     123
# new            77
# NEW            73
# vip            19
# Name: count, dtype: int64

# %%
df["CustomerType"] = df["CustomerType"].str.strip().str.title()

# %%
df["CustomerType"].value_counts(dropna=False)
# Out:
# CustomerType
# Returning    6883
# New          4085
# Vip          1256
# NaN           126
# Name: count, dtype: int64

# %%
df["Region"].value_counts(dropna=False)
# Out:
# Region
# West         2707
# Midwest      2498
# Southeast    2390
# Southwest    2117
# Northeast    2112
# west           70
# WEST           56
# MIDWEST        51
# midwest        50
# NORTHEAST      49
# southeast      46
# NaN            46
# southwest      43
# SOUTHEAST      42
# SOUTHWEST      39
# northeast      34
# Name: count, dtype: int64

# %%
df["Region"] = df["Region"].str.strip().str.title()

# %%
df["Region"].value_counts(dropna=False)
# Out:
# Region
# West         2833
# Midwest      2599
# Southeast    2478
# Southwest    2199
# Northeast    2195
# NaN            46
# Name: count, dtype: int64

# %%
df["State"].value_counts(dropna=False)
# Out:
# State
# NM    743
# OK    733
# TX    730
# WA    607
# OR    602
# CA    562
# AZ    543
# MO    540
# IL    529
# MN    528
# NV    528
# FL    526
# VA    514
# MI    513
# OH    500
# TN    486
# GA    484
# NC    478
# NJ    448
# NY    447
# MA    441
# CT    437
# PA    431
# Name: count, dtype: int64

# %%
df["Product"].value_counts(dropna=False)
# Out:
# Product
# USB-C Hub              739
# Wireless Headphones    729
# Smart Watch            692
# Wireless Mouse         689
# Mechanical Keyboard    682
# Bluetooth Speaker      677
# Desk Lamp              549
# Office Chair           546
# Standing Desk          529
# Notebook Set           516
# Jeans                  509
# Desk Organizer         508
# Jacket                 501
# T-Shirt                481
# Monitor Stand          467
# Backpack               464
# Hoodie                 456
# Running Shoes          419
# Water Bottle           391
# Foam Roller            386
# Dumbbell Set           372
# Yoga Mat               354
# Resistance Bands       354
# Fitness Tracker        340
# Name: count, dtype: int64

# %%
df["SalesChannel"].value_counts(dropna=False)
# Out:
# SalesChannel
# Online          5763
# Retail Store    3302
# Marketplace     2147
# Corporate       1138
# Name: count, dtype: int64

# %%
df["PaymentMethod"].value_counts(dropna=False)
# Out:
# PaymentMethod
# Bank Transfer    2504
# Debit Card       2504
# Credit Card      2485
# Apple Pay        2468
# PayPal           2389
# Name: count, dtype: int64

# %%
df["ShippingMethod"].value_counts(dropna=False)
# Out:
# ShippingMethod
# Standard    6144
# Express     2696
# 2-Day       2220
# Next Day    1203
# NaN           87
# Name: count, dtype: int64

# %%
df["Returned"].value_counts(dropna=False)
# Out:
# Returned
# No     11350
# Yes     1000
# Name: count, dtype: int64

# %% [markdown]
# ## **Step 10: Fix Unit Price**

# %%
df["UnitPrice"].head(25)
# Out:
# 0       36.48
# 1       41.12
# 2      122.56
# 3       26.55
# 4      151.36
# 5      346.78
# 6       47.84
# 7      120.82
# 8      180.22
# 9      133.55
# 10     150.59
# 11    $326.38
# 12      46.03
# 13      84.75
# 14      80.78
# 15      35.47
# 16      34.11
# 17       18.9
# 18     143.09
# 19      66.77
# 20      47.57
# 21     $25.09
# 22      69.97
# 23      38.22
# 24      36.25
# Name: UnitPrice, dtype: str

# %%
df["UnitPrice"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["UnitPrice"] = df["UnitPrice"].str.replace("$", " ", regex=False)

df["UnitPrice"] = pd.to_numeric(df["UnitPrice"], errors="coerce")

# %%
df["UnitPrice"].dtype
df["UnitPrice"].head(20)
# Out:
# 0      36.48
# 1      41.12
# 2     122.56
# 3      26.55
# 4     151.36
# 5     346.78
# 6      47.84
# 7     120.82
# 8     180.22
# 9     133.55
# 10    150.59
# 11    326.38
# 12     46.03
# 13     84.75
# 14     80.78
# 15     35.47
# 16     34.11
# 17     18.90
# 18    143.09
# 19     66.77
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ## **Step 11: Fix dates**
#
# #### **Converting `OrderDate` to Datetime**
#
# * **The following code converts the `OrderDate` column from strings or mixed date formats into Pandas datetime values:**
#
#     ```python
#     df["OrderDate"] = pd.to_datetime(
#         df["OrderDate"],
#         format="mixed",
#         errors="coerce"
#     )
#     ```
#
# * ##### **Step-by-step:**
#
#     * **`df["OrderDate"]`:** Selects the `OrderDate` column from the DataFrame.
#
#     * **`pd.to_datetime()`:** Converts the values into Pandas datetime objects.
#
#     * **`format="mixed"`:** Allows the column to contain dates in different formats.
#
#     * **`errors="coerce"`:** Converts invalid or unrecognized date values to `NaT` instead of raising an error.
#
#     * **`df["OrderDate"] =`:** Stores the converted values back into the `OrderDate` column.
#
#
# * #####  **Why is this useful?**
#
#     Converting the column to datetime makes it easier to perform date-related operations such as sorting, filtering, extracting the year/month/day, and calculating differences between dates.

# %%
df["OrderDate"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"]
                                 , format ="mixed"
                                 , errors="coerce")

# %%
df["OrderDate"].dtype
# Out:
# dtype('<M8[us]')

# %%
df["OrderDate"].head(20)
# Out:
# 0           NaT
# 1           NaT
# 2           NaT
# 3    2026-02-03
# 4           NaT
# 5           NaT
# 6    2026-06-04
# 7           NaT
# 8    2026-04-08
# 9    2026-01-04
# 10          NaT
# 11          NaT
# 12          NaT
# 13          NaT
# 14          NaT
# 15          NaT
# 16   2026-07-03
# 17          NaT
# 18   2025-05-03
# 19          NaT
# Name: OrderDate, dtype: datetime64[us]

# %% [markdown]
# ## **Step 12: How to check null values in a column**

# %%
df["OrderDate"].isnull().sum()
# Out:
# np.int64(9239)

# %% [markdown]
# ## Step 13: **How to handle missing values with Unknowns**

# %%
df.isnull().sum()
# Out:
# OrderID              0
# OrderDate         9239
# CustomerID           0
# CustomerType       126
# Region              46
# State                0
# Product              0
# Category            94
# Quantity             0
# UnitPrice            0
# Discount             0
# SalesChannel         0
# PaymentMethod        0
# ShippingMethod      87
# Returned             0
# CustomerRating    1242
# dtype: int64

# %%
df["CustomerType"] = df["CustomerType"].fillna("Unknown")

# %%
df["Region"] = df["Region"].fillna("Unknown")

# %%
df["Category"] = df["Category"].fillna("Unknown")

# %%
df["ShippingMethod"] = df["ShippingMethod"].fillna("Unknown")

# %%
df["CustomerRating"] = df["CustomerRating"].fillna("Unknown")

# %% [markdown]
# ## **Step 14: How to calculate the final revenue column**

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"] * (1 - df["Discount"])

# %%
# To round the result to a specific number of decimal places
df["Revenue"] = df["Revenue"].round(2)

# %%
df["Revenue"].head()
# Out:
# 0     72.96
# 1     37.01
# 2    104.18
# 3     26.55
# 4    128.66
# Name: Revenue, dtype: float64

# %% [markdown]
# ## **Step 15: Get basic statistics**

# %%
df.describe()
# Out:
#                         OrderDate      Quantity     UnitPrice     Discount  \
# count                        3111  12350.000000  12350.000000  12350.00000
# mean   2025-10-01 22:27:25.515911      1.877976     80.352165      0.05502
# min           2025-01-01 00:00:00      1.000000     17.480000      0.00000
# 25%           2025-05-02 00:00:00      1.000000     34.692500      0.00000
# 50%           2025-09-02 00:00:00      2.000000     60.320000      0.05000
# 75%           2026-03-08 00:00:00      2.000000     95.087500      0.10000
# max           2026-07-09 00:00:00      5.000000    356.390000      0.20000
# std                           NaN      1.081994     69.016987      0.06178
#
#             Revenue
# count  12350.000000
# mean     142.195709
# min       14.250000
# 25%       48.260000
# 50%       86.550000
# 75%      171.287500
# max     1759.000000
# std      164.218425

# %% [markdown]
# ## **Step 16: Start of the Business Questions**

# %% [markdown]
# #### **1- How much revenue did we generate overall?**

# %%
total_revenue = df["Revenue"].sum()
print(f"Total Revenue: ${total_revenue:,.2f}")
# Out:
# Total Revenue: $1,756,117.01

# %% [markdown]
# #### **2- How many orders were placed overall?**

# %%
total_orders = df["OrderID"].nunique()
print(f"Total Orders: {total_orders:,}")
# Out:
# Total Orders: 12,350

# %% [markdown]
# #### **3- How many unique customers did we have overall?**

# %%
total_customers = df["CustomerID"].nunique()
print(f"Total Customers: {total_customers:,}")
# Out:
# Total Customers: 5,115

# %% [markdown]
# #### **4- What was the average order value?**

# %%
avg_order_value = total_revenue / total_orders
print(f"Average Order Value: ${avg_order_value:,.2f}")
# Out:
# Average Order Value: $142.20

# %% [markdown]
# ##### **5- Which products are actually generating the most revenue?**
#
# **`groupby()`:** Split the data into groups based on a specific value, then perform an operation on each group.

# %%
product_revenue = df.groupby("Product")["Revenue"].sum().sort_values(ascending=False)
product_revenue
# Out:
# Product
# Standing Desk          309175.11
# Smart Watch            181747.30
# Office Chair           181157.24
# Mechanical Keyboard    117062.57
# Wireless Headphones    115859.23
# Jacket                 105682.02
# Dumbbell Set            86460.10
# Bluetooth Speaker       81904.69
# Running Shoes           63924.07
# Jeans                   58967.76
# USB-C Hub               53387.45
# Monitor Stand           48914.31
# Fitness Tracker         48869.28
# Wireless Mouse          44851.45
# Hoodie                  44329.59
# Desk Lamp               43134.23
# Backpack                40300.93
# Desk Organizer          22247.46
# Yoga Mat                21960.69
# T-Shirt                 20831.24
# Foam Roller             19095.23
# Notebook Set            17644.80
# Water Bottle            14337.90
# Resistance Bands        14272.36
# Name: Revenue, dtype: float64

# %% [markdown]
# #### **6- Which regions are actually generating the most revenue?**

# %%
region_revenue = df.groupby("Region")["Revenue"].sum().sort_values(ascending=False)
region_revenue
# Out:
# Region
# West         394499.42
# Midwest      372083.68
# Southeast    348688.29
# Southwest    321533.35
# Northeast    314497.43
# Unknown        4814.84
# Name: Revenue, dtype: float64

# %% [markdown]
# #### **7- Which Customer Types are actually generating the most revenue?**

# %%
customer_type_revenue = df.groupby("CustomerType")["Revenue"].sum().sort_values(ascending=False)
customer_type_revenue
# Out:
# CustomerType
# Returning    985307.35
# New          575506.61
# Vip          175756.80
# Unknown       19546.25
# Name: Revenue, dtype: float64

# %% [markdown]
# #### **8- How do customer types compare in terms of total revenue, number of orders, and average order value?**
#
# * ##### **`GroupBy` with `agg()` in Pandas**
#
#     * **`groupby()`:** is used to split the DataFrame into groups based on one or more columns.
#
#     * **`agg()`:** (aggregation) is used to apply one or more aggregate functions to each group.
#
# * ##### **Basic Syntax:**
#
#     ```python
#     df.groupby("group_column").agg(
#         NewColumnName=("column_to_aggregate", "function")
#     )
#     ```
#
#     ###### **Example:**
#
#     ```python
#     customer_type_summary = df.groupby("CustomerType").agg(
#         TotalRevenue=("Revenue", "sum")
#     )
#     ```
#
#     * **Explanation:**
#
#         * **`groupby("CustomerType")`** → Groups the data by customer type.
#
#         * **`("Revenue", "sum")`** → Calculates the sum of `Revenue` for each group.
#
#         * **`TotalRevenue`** → The name given to the resulting column.
#
#         The result will look like:
#
#         ```text
#                     TotalRevenue
#         CustomerType
#         New                 15000
#         Returning           32000
#         ```
#
# * ##### **Multiple Aggregations:**
#
#     **We can apply multiple aggregate functions at the same time:**
#
#     ```python
#     customer_type_summary = df.groupby("CustomerType").agg(
#         TotalRevenue=("Revenue", "sum"),
#         AverageRevenue=("Revenue", "mean"),
#         MaximumRevenue=("Revenue", "max")
#     )
#     ```
#
#     This allows us to calculate multiple summary statistics for each customer type in one operation.
#
# * ##### **Common aggregate functions:**
#
#     * `sum()` → Total value
#     * `mean()` → Average value
#     * `min()` → Minimum value
#     * `max()` → Maximum value
#     * `count()` → Number of non-null values
#     * `nunique()` → Number of unique values
#     * `median()` → Median value

# %%
customer_type_summary = df.groupby("CustomerType").agg(
    TotalRevenue= ("Revenue", "sum"),
    Orders= ("OrderID", "nunique"),
    AvgOrderValue= ("Revenue", "mean")
).sort_values("TotalRevenue", ascending=False)

customer_type_summary
# Out:
#               TotalRevenue  Orders  AvgOrderValue
# CustomerType
# Returning        985307.35    6883     143.150857
# New              575506.61    4085     140.882891
# Vip              175756.80    1256     139.933758
# Unknown           19546.25     126     155.128968

# %% [markdown]
# #### **9- What is the total revenue generated by each sales channel?**

# %%
channel_summary = df.groupby("SalesChannel")["Revenue"].sum().sort_values(ascending=False)

channel_summary
# Out:
# SalesChannel
# Online          816386.02
# Retail Store    466929.14
# Marketplace     310196.42
# Corporate       162605.43
# Name: Revenue, dtype: float64

# %% [markdown]
# #### **10- How many orders and how much revenue are associated with returned and non-returned orders?**

# %%
return_summary = df.groupby("Returned").agg(
    Orders=("OrderID", "nunique"),
    Revenue=("Revenue", "sum")
)

return_summary
# Out:
#           Orders     Revenue
# Returned
# No         11350  1620532.09
# Yes         1000   135584.92

# %% [markdown]
# #### **11- How does total revenue vary from month to month?**

# %%
df["Month"] = df["OrderDate"].dt.to_period("M")

monthly_revenue = df.groupby("Month")["Revenue"].sum()

monthly_revenue
# Out:
# Month
# 2025-01    24918.90
# 2025-02    30001.93
# 2025-03    27931.59
# 2025-04    26934.59
# 2025-05    31455.94
# 2025-06    24162.76
# 2025-07    20663.37
# 2025-08    26691.16
# 2025-09    28791.70
# 2026-01    38512.10
# 2026-02    25707.79
# 2026-03    31669.31
# 2026-04    28296.28
# 2026-05    23100.18
# 2026-06    29196.90
# 2026-07    27636.99
# Freq: M, Name: Revenue, dtype: float64

# %% [markdown]
# ## **Step 17: Save the cleaned data as a CSV file**

# %%
df.to_csv("python_data_analytics_ecommerce_raw_cleaned.csv",
          index=False)
